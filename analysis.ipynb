# %% [markdown]
# # Performance

# %% [markdown]
# ## Jogadores que nunca se encontraram

# %% [markdown]
# ### Neo4j

# %%
from insert_neo4j import InsertCSGO as InsertNeo4j
import time
ic = InsertNeo4j("bolt://localhost:7687", "neo4j", "trabalhobd3")


time_start = time.time()
### Listar jogadores que nunca jogaram juntos
result = ic.run_query("""
MATCH (p1:Player{name: "FalleN"})
OPTIONAL MATCH (p1)-[:PLAYER]->(:Match)<-[:PLAYER]-(p2:Player)
WHERE ID(p1) < ID(p2)
WITH p1, collect(DISTINCT p2) AS metPlayers
MATCH (allPlayers:Player)
WHERE allPlayers <> p1 AND NOT allPlayers IN metPlayers
RETURN count(allPlayers) AS notMetPlayerCount
""")

print("time spent", time.time() - time_start)
print(result.records[0])
# Out:
# time spent 0.027647018432617188
# <Record notMetPlayerCount=2363>

# %% [markdown]
# ### Mysql

# %%
from insert_mysql import InsertCSGO as InsertMySQL

im = InsertMySQL("127.0.0.1", "root", "root", "csgo")

im.establish_connection()

query = """
SELECT count(*)
FROM players p
WHERE p.id NOT IN (
  SELECT DISTINCT p2.id
  FROM players p1
  JOIN player_match pm1 ON p1.id = pm1.player_id
  JOIN player_match pm2 ON pm1.match_id = pm2.match_id
  JOIN players p2 ON pm2.player_id = p2.id
  WHERE p1.name = 'FalleN'
)
AND p.name != 'FalleN';
"""

time_start = time.time()
cursor = im.connection.cursor()
cursor.execute(query)
results = cursor.fetchone()
print("time spent", time.time() - time_start)
print(results)
# Out:
# time spent 0.24468398094177246
# (2341,)

# %% [markdown]
# ## Jogadores que mais encontram outros jogadores
#
# ### Neo4j

# %%
from insert_neo4j import InsertCSGO as InsertNeo4j
import time
ic = InsertNeo4j("bolt://localhost:7687", "neo4j", "trabalhobd3")


time_start = time.time()
### Listar jogadores que nunca jogaram juntos
result = ic.run_query("""
MATCH (p1:Player)
OPTIONAL MATCH (p1)-[:PLAYER]->(:Match)<-[:PLAYER]-(p2:Player)
WITH p1, count(DISTINCT p2) AS metCount
RETURN p1.name AS playerName, metCount
ORDER BY metCount DESC;
""")

print("time spent", time.time() - time_start)
print(result.records)
# Out:
# time spent 0.17109394073486328
# [<Record playerName='ALEX' metCount=335>, <Record playerName='SPELLAN' metCount=297>, <Record playerName='SHiPZ' metCount=277>, <Record playerName='phr' metCount=264>, <Record playerName='Furlan' metCount=262>, <Record playerName='bubble' metCount=260>, <Record playerName='MINISE' metCount=260>, <Record playerName='qikert' metCount=256>, <Record playerName='facecrack' metCount=256>, <Record playerName='b0RUP' metCount=255>, <Record playerName='acoR' metCount=253>, <Record playerName='buster' metCount=253>, <Record playerName='Jerry' metCount=253>, <Record playerName='GruBy' metCount=252>, <Record playerName='steel' metCount=251>, <Record playerName='es3tag' metCount=249>, <Record playerName='poizon' metCount=246>, <Record playerName='hampus' metCount=245>, <Record playerName='HUNDEN' metCount=244>, <Record playerName='AcilioN' metCount=244>, <Record playerName='ZOREE' metCount=243>, <Record playerName='v1c7oR' metCount=243>, <Record playerName='YEKINDAR' metCount=242>, <Record playerName='snatchie' metCount=242>, <Record playerName='rallen' metCount=240>, <Record playerName='ottoNd' metCount=239>, <Record playerName='FREDDyFROG' metCount=237>, <Record playerName='reatz' metCount=236>, <Record playerName='mouz' metCount=236>, <Record playerName='nexa' metCount=235>, <Record playerName='Lucky' metCount=235>, <Record playerName='Relaxa' metCount=234>, <Record playerName='Jame' metCount=231>, <Record playerName='almazer' metCount=230>, <Record playerName='xsepower' metCount=228>, <Record playerName='stavn' metCount=228>, <Record playerName='KrizzeN' metCount=227>, <Record playerName='sergej' metCount=226>, <Record playerName='sAw' metCount=226>, <Record playerName='mertz' metCount=226>, <Record playerName='huNter-' metCount=225>, <Record playerName='STYKO' metCount=225>, <Record playerName='RuStY' metCount=224>, <Record playerName='EspiranTo' metCount=224>, <Record playerName='MICHU' metCount=223>, <Record playerName='faveN' metCount=222>, <Record playerName='Bubzkji' metCount=221>, <Record playerName='JaCkz' metCount=220>, <Record playerName='mds' metCount=219>, <Record playerName='denis' metCount=219>, <Record playerName='refrezh' metCount=219>, <Record playerName='frozen' metCount=218>, <Record playerName='sLowi' metCount=218>, <Record playerName='LETN1' metCount=217>, <Record playerName='Spiidi' metCount=216>, <Record playerName='dimasick' metCount=214>, <Record playerName='blocker' metCount=214>, <Record playerName='CeRq' metCount=212>, <Record playerName='xartE' metCount=212>, <Record playerName='TaZ' metCount=212>, <Record playerName='lollipop21k' metCount=211>, <Record playerName='syrsoN' metCount=211>, <Record playerName='KHRN' metCount=211>, <Record playerName='Maka' metCount=209>, <Record playerName='zehN' metCount=209>, <Record playerName='freddieb' metCount=208>, <Record playerName='nukkye' metCount=208>, <Record playerName='Aleksib' metCount=207>, <Record playerName='somedieyoung' metCount=207>, <Record playerName='Rock1nG' metCount=206>, <Record playerName='Boombl4' metCount=205>, <Record playerName='tiziaN' metCount=205>, <Record playerName='SZPERO' metCount=205>, <Record playerName='FL1T' metCount=204>, <Record playerName='Davidp' metCount=204>, <Record playerName='Flarich' metCount=204>, <Record playerName='cadiaN' metCount=204>, <Record playerName='sjuush' metCount=202>, <Record playerName='Jyo' metCount=202>, <Record playerName='boX' metCount=200>, <Record playerName='Dima' metCount=199>, <Record playerName='S0tF1k' metCount=199>, <Record playerName='Snappi' metCount=198>, <Record playerName='TOAO' metCount=198>, <Record playerName='nawwk' metCount=197>, <Record playerName='gade' metCount=197>, <Record playerName='morelz' metCount=197>, <Record playerName='kRYSTAL' metCount=196>, <Record playerName='PlesseN' metCount=196>, <Record playerName='Kvik' metCount=196>, <Record playerName='Console' metCount=196>, <Record playerName='AdreN' metCount=195>, <Record playerName='Brollan' metCount=195>, <Record playerName=' ...

# %% [markdown]
# ### Mysql

# %%
from insert_mysql import InsertCSGO as InsertMySQL

im = InsertMySQL("127.0.0.1", "root", "root", "csgo")

im.establish_connection()

query = """
SELECT p.name AS playerName, COUNT(DISTINCT pm2.player_id) AS metCount
FROM players p
LEFT JOIN player_match pm1 ON p.id = pm1.player_id
LEFT JOIN player_match pm2 ON pm1.match_id = pm2.match_id
                          AND pm1.player_id != pm2.player_id
WHERE pm2.player_id IS NOT NULL
GROUP BY p.id
ORDER BY metCount DESC;
"""

time_start = time.time()
cursor = im.connection.cursor()
cursor.execute(query)
results = cursor.fetchall()
print("time spent", time.time() - time_start)
print(results)
# Out:
# time spent 0.382000207901001
# [('SPELLAN', 299), ('SHiPZ', 277), ('phr', 265), ('Furlan', 262), ('MINISE', 261), ('bubble', 260), ('b0RUP', 257), ('facecrack', 256), ('qikert', 256), ('acoR', 253), ('buster', 253), ('Jerry', 253), ('GruBy', 252), ('es3tag', 251), ('hampus', 247), ('poizon', 246), ('AcilioN', 245), ('HUNDEN', 244), ('v1c7oR', 243), ('ZOREE', 243), ('snatchie', 243), ('YEKINDAR', 243), ('rallen', 240), ('ottoNd', 240), ('FREDDyFROG', 238), ('reatz', 236), ('mouz', 236), ('Relaxa', 235), ('nexa', 235), ('Jame', 231), ('almazer', 230), ('stavn', 229), ('xsepower', 228), ('mertz', 227), ('KrizzeN', 227), ('sAw', 226), ('RuStY', 226), ('sergej', 226), ('huNter-', 225), ('STYKO', 225), ('EspiranTo', 225), ('MICHU', 223), ('faveN', 223), ('JaCkz', 221), ('Bubzkji', 221), ('denis', 220), ('mds', 220), ('frozen', 219), ('refrezh', 219), ('sLowi', 218), ('LETN1', 217), ('Spiidi', 217), ('blocker', 214), ('dimasick', 214), ('CeRq', 213), ('TaZ', 212), ('syrsoN', 212), ('xartE', 212), ('lollipop21k', 212), ('KHRN', 211), ('Maka', 210), ('zehN', 209), ('freddieb', 209), ('somedieyoung', 208), ('nukkye', 208), ('Aleksib', 207), ('Rock1nG', 207), ('SZPERO', 205), ('tiziaN', 205), ('Davidp', 205), ('Boombl4', 205), ('cadiaN', 204), ('Flarich', 204), ('FL1T', 204), ('Lucky', 204), ('ALEX', 203), ('Jyo', 203), ('steel', 202), ('sjuush', 202), ('ALEX', 200), ('S0tF1k', 200), ('boX', 200), ('Snappi', 199), ('Dima', 199), ('TOAO', 198), ('nawwk', 198), ('morelz', 197), ('gade', 197), ('kRYSTAL', 196), ('Kvik', 196), ('PlesseN', 196), ('Console', 196), ('k1to', 196), ('AdreN', 195), ('ROBO', 195), ('djL', 195), ('Brollan', 195), ('Maikelele', 194), ('mopoz', 193), ('NickelBack', 193), ('Snax', 192), ('AmaNEk', 192), ('Aerial', 190), ('BnTeT', 190), ('def', 188), ('TENZKI', 187), ('somebody', 186), ('niki1', 186), ('Ryxxo', 184), ('COLDYY1', 184), ('XANTARES', 183), ('kenzor', 183), ('kressy', 183), ('Basso', 182), ('stanislaw', 181), ('AiyvaN', 181), ('Plopski', 181), ('blameF', 180), ('bondik', 179), ('Brehze', 179), ('arvid', 179), ('ANGE1', 178), ('FalleN', 178), ('fenvicious', 178), ('yuurih', 178), ('pNshr', 177), ('flamie', 177), ('speed4k', 177), ('JiNKZ', 177), ('twist', 176), ('crisby', 175), ('tabseN', 175), ('kennyS', 175), ('mixwell', 175), ('ZywOo', 175), ('stfN', 174), ('niko', 174), ('RpK', 173), ('fer', 173), ('dennis', 172), ('DavCost', 172), ('Krad', 172), ('Forester', 172), ('Stewie2K', 171), ('Nifty', 171), ('xccurate', 171), ('Ethan', 171), ('VINI', 171), ('PASHANOJ', 171), ('oskarish', 170), ('TeSeS', 170), ('friberg', 169), ('MSL', 169), ('NaToSaphiX', 169), ('mono', 169), ('arT', 169), ('hoody', 169), ('roeJ', 169), ('Goofy', 169), ('kzy', 168), ('robiin', 168), ('Bååten', 168), ('chrisJ', 167), ('chopper', 167), ('ISSAA', 167), ('ropz', 167), ('WorldEdit', 166), ('woxic', 165), ('iDk', 165), ('Thomas', 165), ('LOGAN', 165), ('Farlig', 165), ('Hobbit', 164), ('nex', 163), ('Edward', 162), ('EliGE', 162), ('Twistzz', 162), ('cromen', 162), ('torben', 162), ('shox', 161), ('RUBINO', 161), ('Lukki', 161), ('kinqie', 160), ('loWel', 160), ('s1mple', 160), ('Kjaerbye', 160), ('NAF', 160), ('disco doplan', 160), ('REZ', 160), ('kaper', 160), ('allu', 159), ('daps', 159), ('dragonfly', 159), ('PERCY', 158), ('DD', 158), ('xseveN', 158), ('mirbit', 158), ('SANJI', 158), ('R0b3n', 158), ('KSCERATO', 158), ('AZR', 157), ('darko', 157), ('Zeus', 156), ('JW', 156), ('apEX', 156), ('nitr0', 156), ('wayLander', 156), ('electronic', 156), ('TACO', 156), ('AnJ', 156), ('hAdji', 156), ('innocent', 155), ('kNgV-', 155), ('oSee', 155), ('oskar', 154), ('hitMouse', 154), ('aizy', 154), ('FugLy', 154), ('malta', 154), ('SADDYX', 154), ('emi', 153), ('jks', 153), ('valde', 153), ('crush', 153), ('lunAtic', 153), ('svyat', 153), ('El1an', 153), ('ScreaM', 152), ('FANAT ROCKA', 152), ('Surreal', 152), ('RCF', 152), ('STOMP', 152), ('mou', 151), ('jkaem', 151), ('Nodios', 151), ('hallzerk', 151), ('Radifaction', 151), ('k0nfig', 150), ('karrigan', 149), ('CRUC1AL ...
